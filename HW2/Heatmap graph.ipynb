# %%
import seaborn as sn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
df1 = pd.read_csv('/Users/Kang/Documents/碩一下學期/石百達 金融科技-文字探勘與機器學習 /Week 5,6 HW2/read_pdf_and_jieba/csv/cooccurance_m_has_row_1.csv', encoding = 'big5hkscs')

# %%
df1.set_index('keyword', inplace = True)
df1
# Out:
#          # 股票   國內  公司股票   上市    證券   產業    價格   憑證  ETF   信託 ...  成立  經濟建設  \
# keyword                                                       ...
# # 股票     2168  234   119  384   587  923   947  410  420  156 ...  35    21
# 國內        234  184    70  111   132  127   136   90  141   84 ...  20    12
# 公司股票      119   70    49   56    28   68    68   49   51   41 ...  10     6
# 上市        384  111    56  161   144  171   187   98   94   67 ...  15     9
# 證券        587  132    28  144   868  243   455   61  146   46 ...   0     0
# 產業        923  127    68  171   243  758   524  168  241   78 ...  10     6
# 價格        947  136    68  187   455  524   825  172  246   88 ...  20    12
# 憑證        410   90    49   98    61  168   172  150  136   58 ...  15     9
# ETF       420  141    51   94   146  241   246  136  505   92 ...  15     9
# 信託        156   84    41   67    46   78    88   58   92   54 ...  10     6
# ...

# %%
sn.set(font_scale=2)

# %%
plt.rcParams['font.family'] = ['Microsoft JhengHei']
plt.figure(figsize=(40, 30))
sn.heatmap(df1, cmap='Reds', robust=True)
